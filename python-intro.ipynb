# %% [markdown]
# <a href="https://colab.research.google.com/github/SurZen/Python-Gapminder-Data/blob/main/python-intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro Python colab - jup notebook
#
# Weekend Carp1
#
# **Bolded**

# %%
import math

print('pi is', math.pi)
print('cos(pi)is', math.cos(math.pi))#put imports at start of notebook
# Out:
# pi is 3.141592653589793
# cos(pi)is -1.0

# %%
age = 38
name = "Sherap"
last_name = "Sangpo"

# %%
print(age)
# Out:
# 38

# %%
print(name, "is" , age, "years old", '.' )
# Out:
# Sherap is 38 years old .

# %%
print(last_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a637c5453549> in <cell line: 0>()
# ----> 1 print(last_name)
#
# NameError: name 'last_name' is not defined

# %%
last_name = "Sangpo"
print(last_name)
# Out:
# Sangpo

# %%
print(name, "will be", age+10, "in ten years.")
# Out:
# Sherap will be 48 in ten years.

# %%
print(name[2])
# Out:
# e

# %%
print(name[0])
# Out:
# S

# %%
name_substring = name[0:3]
print(name_substring)
# Out:
# She

# %%
length_name = len(name)
print(length_name+4)
# Out:
# 16

# %%
ccd1 = 0
cC1 = 2
print(ccd1)
print(cC1)
# Out:
# 0
# 2

# %%
#alteration of original veriable (follow original synyax) - updated originial uses of the veriable.
name = "Sherapsnagpo"
print(name)
# Out:
# Sherapsnagpo

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
new_age = "20"
print(new_age+15)
# Out:
# Dog

# %%
new_age = int(new_age)

# %%
new_age + 50
# Out:
# 70

# %%
num = 5.0923

# %%
type(num)
# Out:
# float

# %%
num - 0.856473
# Out:
# 4.235827

# %%
num * 3
# Out:
# 15.2769

# %%
num / 0.5
# Out:
# 10.1846

# %%
integer = 4
print(integer/3)
# Out:
# 1.3333333333333333

# %%
type(integer/3
)
# Out:
# float

# %%
ND = num * 3 [3:4]
print(ND)
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <ipython-input-44-39b4a2e0e095>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   ND = num * 3 [3:4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-39b4a2e0e095> in <cell line: 0>()
# ----> 1 ND = num * 3 [3:4]
#       2 print(ND)
#
# TypeError: 'int' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2bede0707480> in <cell line: 0>()
#       2 df = 67
#       3 dw = da * df
# ----> 4 q = dw[0:1]
#       5 print(dw)
#
# TypeError: 'int' object is not subscriptable

# %%
print("hello world")
print()
print('helo', 'world', 'again') #()= argument. print = funtion
# Out:
# hello world
#
# helo world again

# %%
result = print('example')
print('result of print is', result)
# Out:
# example
# result of print is None

# %%
print(max(0,1,2,3))
print(min('a,','A','0'))
# Out:
# 3
# 0

# %%
round(3.714, 2) #default is nearest whole number  or use ngigets ,2 in this case.
# Out:
# 3.71

# %%
my_string = 'Hello world!'
print(len(my_string)) #printing length of my_string
print(my_string.swapcase())#. adds a function to what its connected to () denotes a function and not refrencing a varible.
# Out:
# 12
# hELLO WORLD!

# %%
print(my_string.isupper())#logical ask of if .isupper is t/f
# Out:
# False

# %%
print (my_string.isupper())
print(my_string.upper())
# Out:
# False
# HELLO WORLD!

# %%
print(my_string.upper().isupper())# varifies condition of .upper/isupper is both true.
# Out:
# True

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
radiance = 1.0
radiance = max(2.1, 2.0 + min(radiance, 1.1 * radiance - 0.5))
print(radiance)
# Out:
# 2.6

# %%
import math

print('pi is', math.pi)
print('cos(pi)is', math.cos(math.pi))
# Out:
# pi is 3.141592653589793
# cos(pi)is -1.0

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
from math import cos, pi #would only import those packs and not whole packg.

# %%
import pandas as pd

# %%
data_oceania = pd.read_csv('/content/data/gapminder_gdp_oceania.csv', index_col= 'country')
print(data_oceania)
#addition of index_col to rename colum
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data_oceania.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gdpPercap_1952  2 non-null      float64
#  1   gdpPercap_1957  2 non-null      float64
#  2   gdpPercap_1962  2 non-null      float64
#  3   gdpPercap_1967  2 non-null      float64
#  4   gdpPercap_1972  2 non-null      float64
#  5   gdpPercap_1977  2 non-null      float64
#  6   gdpPercap_1982  2 non-null      float64
#  7   gdpPercap_1987  2 non-null      float64
#  8   gdpPercap_1992  2 non-null      float64
#  9   gdpPercap_1997  2 non-null      float64
#  10  gdpPercap_2002  2 non-null      float64
#  11  gdpPercap_2007  2 non-null      float64
# dtypes: float64(12)
# memory usage: 316.0+ bytes

# %%
print(data_oceania.columns)#types of colums in data
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(data_oceania.T)
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
print(data_oceania.describe())#shows helpful values on values.
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
# shell commands from jupyter
# !mkdir data
# !mv *.csv
# !ls data

# %%
data_americas = pd.read_csv('/content/data/gapminder_gdp_americas.csv', index_col= 'country')
print(data_americas)
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
print(data_americas.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
help(data_americas.head)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n: 'int' = 5) -> 'Self' method of pandas.core.frame.DataFrame instance
#     Return the first `n` rows.
#
#     This function returns the first `n` rows for the object based
#     on position. It is useful for quickly testing if your object
#     has the right type of data in it.
#
#     For negative values of `n`, this function returns all rows except
#     the last `|n|` rows, equivalent to ``df[:n]``.
#
#     If n is larger than the number of rows, this function returns all rows.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     same type as caller
#         The first `n` rows of the caller object.
#
#     See Also
#     --------
#     DataFrame.tail: Returns the last `n` rows.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'animal': ['alligator', 'bee', 'falcon', 'lion',
# ...

# %%
print(data_americas.head())
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# ...

# %%
print(data_americas.tail())
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Puerto Rico          Americas     3081.959785     3907.156189     5108.344630
# Trinidad and Tobago  Americas     3023.271928     4100.393400     4997.523971
# United States        Americas    13990.482080    14847.127120    16173.145860
# Uruguay              Americas     5716.766744     6150.772969     5603.357717
# Venezuela            Americas     7689.799761     9802.466526     8422.974165
#
#                      gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Puerto Rico             6929.277714     9123.041742     9770.524921
# Trinidad and Tobago     5621.368472     6619.551419     7899.554209
# United States          19530.365570    21806.035940    24072.632130
# Uruguay                 5444.619620     5703.408898     6504.339663
# Venezuela               9541.474188    10505.259660    13143.950950
#
# ...

# %%
data_americas.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
#[row,col] standard

# %%
data_americas
data_americas.iloc[0,0]
# Out:
# 'Americas'

# %%
data_americas
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
data_americas.loc['Argentina',"gdpPercap_1952"]
#import numpy as np$ get GDP of argentina in 1952
# Out:
# np.float64(5911.315053)

# %%
print(data_americas.loc['Canada', :])
# Out:
# continent            Americas
# gdpPercap_1952    11367.16112
# gdpPercap_1957    12489.95006
# gdpPercap_1962    13462.48555
# gdpPercap_1967    16076.58803
# gdpPercap_1972    18970.57086
# gdpPercap_1977    22090.88306
# gdpPercap_1982    22898.79214
# gdpPercap_1987    26626.51503
# gdpPercap_1992    26342.88426
# gdpPercap_1997    28954.92589
# gdpPercap_2002    33328.96507
# gdpPercap_2007    36319.23501
# Name: Canada, dtype: object

# %%
data_carp = data_americas.drop('continent') #continent is not in axis being searched for
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-6cde76f31150> in <cell line: 0>()
# ----> 1 data_carp = data_americas.drop('continent')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
data_carp = data_americas.drop('continent', axis = 1)

# %%
data_carp
# Out:
#                      gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina               5911.315053     6856.856212     7133.166023
# Bolivia                 2677.326347     2127.686326     2180.972546
# Brazil                  2108.944355     2487.365989     3336.585802
# Canada                 11367.161120    12489.950060    13462.485550
# Chile                   3939.978789     4315.622723     4519.094331
# Colombia                2144.115096     2323.805581     2492.351109
# Costa Rica              2627.009471     2990.010802     3460.937025
# Cuba                    5586.538780     6092.174359     5180.755910
# Dominican Republic      1397.717137     1544.402995     1662.137359
# Ecuador                 3522.110717     3780.546651     4086.114078
# El Salvador             3048.302900     3421.523218     3776.803627
# Guatemala               2428.237769     2617.155967     2750.364446
# Haiti                   1840.366939     1726.887882     1796.589032
# ...

# %%
print(data_americas.loc[:, 'gdpPercap_1952'])
# equivalent to
print(data_americas['gdpPercap_1952'])
# Out:
# country
# Argentina               5911.315053
# Bolivia                 2677.326347
# Brazil                  2108.944355
# Canada                 11367.161120
# Chile                   3939.978789
# Colombia                2144.115096
# Costa Rica              2627.009471
# Cuba                    5586.538780
# Dominican Republic      1397.717137
# Ecuador                 3522.110717
# El Salvador             3048.302900
# Guatemala               2428.237769
# Haiti                   1840.366939
# Honduras                2194.926204
# Jamaica                 2898.530881
# Mexico                  3478.125529
# Nicaragua               3112.363948
# Panama                  2480.380334
# Paraguay                1952.308701
# Peru                    3758.523437
# Puerto Rico             3081.959785
# Trinidad and Tobago     3023.271928
# United States          13990.482080
# Uruguay                 5716.766744
# Venezuela               7689.799761
# Name: gdpPercap_1952, dtype: float64
# ...

# %%
data_carp.loc['Canada':'Cuba', 'gdpPercap_1962': 'gdpPercap_1972' ]
# all countrys starting with c between 1962 - 1972
# Out:
#             gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Canada        13462.485550    16076.588030    18970.570860
# Chile          4519.094331     5106.654313     5494.024437
# Colombia       2492.351109     2678.729839     3264.660041
# Costa Rica     3460.937025     4161.727834     5118.146939
# Cuba           5180.755910     5690.268015     5305.445256

# %%
data_carp.loc['Canada':'Cuba', 'gdpPercap_1962': 'gdpPercap_1972' ].max()
# Out:
# gdpPercap_1962    13462.48555
# gdpPercap_1967    16076.58803
# gdpPercap_1972    18970.57086
# dtype: float64

# %%
data_carp.loc['Canada':'Cuba', 'gdpPercap_1962': 'gdpPercap_1972' ].min()
# Out:
# gdpPercap_1962    2492.351109
# gdpPercap_1967    2678.729839
# gdpPercap_1972    3264.660041
# dtype: float64

# %%
data_carp.loc['Cuba':'Canada', 'gdpPercap_1962': 'gdpPercap_1972' ]
#not able to revers slice in the situation
# Out:
# Empty DataFrame
# Columns: [gdpPercap_1962, gdpPercap_1967, gdpPercap_1972]
# Index: []

# %%
mask = data_carp['gdpPercap_1952']>3000

# %%
mask
# Out:
# country
# Argentina               True
# Bolivia                False
# Brazil                 False
# Canada                  True
# Chile                   True
# Colombia               False
# Costa Rica             False
# Cuba                    True
# Dominican Republic     False
# Ecuador                 True
# El Salvador             True
# Guatemala              False
# Haiti                  False
# Honduras               False
# Jamaica                False
# Mexico                  True
# Nicaragua               True
# Panama                 False
# Paraguay               False
# Peru                    True
# Puerto Rico             True
# Trinidad and Tobago     True
# United States           True
# Uruguay                 True
# Venezuela               True
# Name: gdpPercap_1952, dtype: bool

# %%
data_carp[-mask]
# Out:
#                     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Bolivia                2677.326347     2127.686326     2180.972546
# Brazil                 2108.944355     2487.365989     3336.585802
# Colombia               2144.115096     2323.805581     2492.351109
# Costa Rica             2627.009471     2990.010802     3460.937025
# Dominican Republic     1397.717137     1544.402995     1662.137359
# Guatemala              2428.237769     2617.155967     2750.364446
# Haiti                  1840.366939     1726.887882     1796.589032
# Honduras               2194.926204     2220.487682     2291.156835
# Jamaica                2898.530881     4756.525781     5246.107524
# Panama                 2480.380334     2961.800905     3536.540301
# Paraguay               1952.308701     2046.154706     2148.027146
#
#                     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Bolivia                2586.886053     2980.331339     3548.097832
# ...

# %%
mask_higher = data_carp > data_carp.mean()

# %%
mask_higher
# Out:
#                      gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina                      True            True            True
# Bolivia                       False           False           False
# Brazil                        False           False           False
# Canada                         True            True            True
# Chile                         False           False           False
# Colombia                      False           False           False
# Costa Rica                    False           False           False
# Cuba                           True            True            True
# Dominican Republic            False           False           False
# Ecuador                       False           False           False
# El Salvador                   False           False           False
# Guatemala                     False           False           False
# Haiti                         False           False           False
# ...

# %%
mask_higher.aggregate('sum', axis = 1) / len(data_carp.columns)
mask_higher = data_carp > data_carp.mean()
# wealth score
wealth_score = mask_higher.aggregate('sum', axis = 1) / len(data_carp.columns)

# %%
print(wealth_score)
# Out:
# country
# Argentina              0.916667
# Bolivia                0.000000
# Brazil                 0.083333
# Canada                 1.000000
# Chile                  0.250000
# Colombia               0.000000
# Costa Rica             0.000000
# Cuba                   0.333333
# Dominican Republic     0.000000
# Ecuador                0.000000
# El Salvador            0.000000
# Guatemala              0.000000
# Haiti                  0.000000
# Honduras               0.000000
# Jamaica                0.333333
# Mexico                 0.750000
# Nicaragua              0.000000
# Panama                 0.000000
# Paraguay               0.000000
# Peru                   0.166667
# Puerto Rico            0.833333
# Trinidad and Tobago    0.500000
# United States          1.000000
# Uruguay                0.416667
# Venezuela              0.916667
# dtype: float64

# %%
print( mask_higher.aggregate('sum', axis=1))
# total type each country recived true for value being greater than the mean gdp
# Out:
# country
# Argentina              11
# Bolivia                 0
# Brazil                  1
# Canada                 12
# Chile                   3
# Colombia                0
# Costa Rica              0
# Cuba                    4
# Dominican Republic      0
# Ecuador                 0
# El Salvador             0
# Guatemala               0
# Haiti                   0
# Honduras                0
# Jamaica                 4
# Mexico                  9
# Nicaragua               0
# Panama                  0
# Paraguay                0
# Peru                    2
# Puerto Rico            10
# Trinidad and Tobago     6
# United States          12
# Uruguay                 5
# Venezuela              11
# dtype: int64

# %%
data_carp.groupby(wealth_score).mean()
#mean wealth score above ave
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000     2452.097130     2601.489888     2818.029826     3217.947786
# 0.083333     2108.944355     2487.365989     3336.585802     3429.864357
# 0.166667     3758.523437     4245.256698     4957.037982     5788.093330
# 0.250000     3939.978789     4315.622723     4519.094331     5106.654313
# 0.333333     4242.534830     5424.350070     5213.431717     5907.485733
# 0.416667     5716.766744     6150.772969     5603.357717     5444.619620
# 0.500000     3023.271928     4100.393400     4997.523971     5621.368472
# 0.750000     3478.125529     4131.546641     4581.609385     5754.733883
# 0.833333     3081.959785     3907.156189     5108.344630     6929.277714
# 0.916667     6800.557407     8329.661369     7778.070094     8797.213605
# 1.000000    12678.821600    13668.538590    14817.815705    17803.476800
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# ...

# %%
data_all = pd.read_csv('/content/data/gapminder_all.csv')

# %%
data_all
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %%
data_all[data_all['continent']!= 'Africa']
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 52   Americas       Argentina     5911.315053     6856.856212     7133.166023
# 53   Americas         Bolivia     2677.326347     2127.686326     2180.972546
# 54   Americas          Brazil     2108.944355     2487.365989     3336.585802
# 55   Americas          Canada    11367.161120    12489.950060    13462.485550
# 56   Americas           Chile     3939.978789     4315.622723     4519.094331
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %%
AFD = data_all.loc[data_all['continent']== 'Africa', 'gdpPercap_1952']

# %%
import matplotlib.pyplot as plt
import numpy as np

data_all.loc[data_all['continent']== 'Africa', 'gdpPercap_1952'].plot.bar()
#need () to call not just ref.
AFD['gdpPercap_1952'].plot.bar()
plt.xticks(np.arange(0, 52, 1), labels = AFD['country'].values)
#still need to set x axis to countries
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'gdpPercap_1952'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-176-dbeb1fd92525> in <cell line: 0>()
#       4 data_all.loc[data_all['continent']== 'Africa', 'gdpPercap_1952'].plot.bar()
#       5 #need () to call not just ref.
# ----> 6 AFD['gdpPercap_1952'].plot.bar()
# ...
